# %%
import pandas as pd

# %%
df_2019_Oct = pd.read_csv("../dataset/2019-Oct.csv.gz", nrows=1000000)

# %%
df_2019_Oct
# Out:
#                      event_time event_type  product_id          category_id  \
# 0       2019-10-01 00:00:00 UTC       view    44600062  2103807459595387724
# 1       2019-10-01 00:00:00 UTC       view     3900821  2053013552326770905
# 2       2019-10-01 00:00:01 UTC       view    17200506  2053013559792632471
# 3       2019-10-01 00:00:01 UTC       view     1307067  2053013558920217191
# 4       2019-10-01 00:00:04 UTC       view     1004237  2053013555631882655
# ...                         ...        ...         ...                  ...
# 999995  2019-10-01 16:56:07 UTC       view     1005115  2053013555631882655
# 999996  2019-10-01 16:56:07 UTC       view    26403239  2053013563651392361
# 999997  2019-10-01 16:56:07 UTC       view     1307338  2053013558920217191
# 999998  2019-10-01 16:56:07 UTC       view     1004873  2053013555631882655
# 999999  2019-10-01 16:56:07 UTC       view     2400496  2053013563743667055
#
# ...
